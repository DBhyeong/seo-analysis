# %%
#성경 구절 

from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
import urllib
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
from datetime import datetime,timedelta
import warnings
import xmltodict # 결과가 xml 형식으로 반환된다. 이것을 dict 로 바꿔주는 라이브러리다
import time

#lang 언어선택 (kor 고정)

#문서선택

#------------------ 구약(예수 전) ------------------
# ge 창세기
# exo 출애굽기
# lev 레위기
# num 민수기
# deu 신명기
# josh 여호수아
# jdgs 사사기
# ruth 룻기
# 1sm 사무엘상
# 2sm 사무엘하
# 1ki 열왕기상
# 2ki 열왕기하
# 1chr 역대상
# 2chr 역대하
# ezra 에스라
# neh 느헤미야
# est 에스더
# job 욥기
# psa 시편
# prv 잠언
# eccl 전도서
# ssol 아가
# isa 이사야
# jer 예레미야
# lam 예레미야 애가
# eze 에스겔
# dan 다니엘
# hos 호세아
# joel 요엘
# amos 아모스
# obad 오바댜
# jonah 요나
# mic 미가
# nahum 나훔
# hab 하박국
# zep 스바냐
# hag 학개
# zep 스가랴
# mal 말라기

#------------------- 신약(예수 온날) -------------------
# mat 마태복음
# mark 마가복음
# luke 누가복음
# john 요한복음
# acts 사도행전
# rom 로마서
# 1cor 고린도전서
# 2cor 고린도후서
# gal 갈라디아서
# eph 에베소서
# phi 빌립보서
# col 골로새서
# 1th 데살로니가전서
# 2th 데살로니가후서
# 1tim 디모데전서
# 2tim 디모데후서
# titus 디도서
# phmn 빌레몬서
# heb 히브리서
# jas 야고보서
# 1pet 베드로전서
# 2pet 베드로후서
# 1jn 요한1서
# 2jn 요한2서
# 3jn 요한3서
# jude 유다서
# rev 요한계시록


#시작위치

#1 : 1 (고정)
#종료위치

#500 : 1000 (해보자)

warnings.filterwarnings('ignore')


docs = [ 'ge',
'exo',
'lev',
'num',
'deu',
'josh',
'jdgs',
'ruth',
'1sm',
'2sm',
'1ki',
'2ki',
'1chr',
'2chr',
'ezra',
'neh',
'est',
'job',
'psa',
'prv',
'eccl',
'ssol',
'isa',
'jer',
'lam',
'eze',
'dan',
'hos',
'joel',
'amos',
'obad',
'jonah',
'mic',
'nahum',
'hab',
'zep',
'hag',
'zep',
'mal',
'mat',
'mark',
'luke',
'john',
'acts',
'rom',
'1cor',
'2cor',
'gal',
'eph',
'phi',
'col',
'1th',
'2th',
'1tim',
'2tim',
'titus',
'phmn',
'heb',
'jas',
'1pet',
'2pet',
'1jn',
'2jn',
'3jn',
'jude',
'rev'
    
]


for doc in docs :
    #doc = 'ge' #창세기
    url = 'https://yesu.io/bible?lang=kor&doc={}&start=1:1&end=1000:3000'.format(doc)

    headers = { 'Accept-Language' : 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7,zh-TW;q=0.6,zh;q=0.5',
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/100.0.4896.127 Safari/537.36',
                'Accept-Encoding': 'gzip'
    }

    response = requests.get(url=url, headers=headers, verify=False)

    #html = BeautifulSoup(raw.content.decode('euc-kr', 'replace'), 'html.parser')
    #html = BeautifulSoup(raw.text, 'html.parser')
    #print(html.prettify())
    #results = html.find_all('select')
    #print(results[1].text)

    r_data = response.json() #json 파일화

    max_chapter = r_data[len(r_data)-1]['chapter']  #최대 챕터

    for chapter in range(1, int(max_chapter)+1) : #최대 챕터 기준
        #n = 0
        f = open('C:/Users/user/raw/down/bible/'+str(doc)+'_'+str(chapter)+'_verse.txt', 'w', encoding='utf-8-sig') #메모장 열기

        for n in range(0, len(r_data)) : #전체 행기준
            if str(chapter) == r_data[n]['chapter'] :
                verse = r_data[n]['verse']
                message = r_data[n]['message']
                f.write(str(chapter)+ "장 "+ str(verse) +'절 '+ message+'\n')
            else :  #멈추는걸 하지 않는다.
                continue
        f.close()  #메모장 닫기
        
        print(str(doc) + "의 챕터:" + str(chapter) + "장의 처리 완료했습니다.")
        time.sleep(1) #1초
    print(str(doc) +"의 최종 처리 완료")
# Out:
# ge의 챕터:1장의 처리 완료했습니다.
# ge의 챕터:2장의 처리 완료했습니다.
# ge의 챕터:3장의 처리 완료했습니다.
# ge의 챕터:4장의 처리 완료했습니다.
# ge의 챕터:5장의 처리 완료했습니다.
# ge의 챕터:6장의 처리 완료했습니다.
# ge의 챕터:7장의 처리 완료했습니다.
# ge의 챕터:8장의 처리 완료했습니다.
# ge의 챕터:9장의 처리 완료했습니다.
# ge의 챕터:10장의 처리 완료했습니다.
# ge의 챕터:11장의 처리 완료했습니다.
# ge의 챕터:12장의 처리 완료했습니다.
# ge의 챕터:13장의 처리 완료했습니다.
# ge의 챕터:14장의 처리 완료했습니다.
# ge의 챕터:15장의 처리 완료했습니다.
# ge의 챕터:16장의 처리 완료했습니다.
# ge의 챕터:17장의 처리 완료했습니다.
# ge의 챕터:18장의 처리 완료했습니다.
# ge의 챕터:19장의 처리 완료했습니다.
# ge의 챕터:20장의 처리 완료했습니다.
# ge의 챕터:21장의 처리 완료했습니다.
# ge의 챕터:22장의 처리 완료했습니다.
# ge의 챕터:23장의 처리 완료했습니다.
# ge의 챕터:24장의 처리 완료했습니다.
# ge의 챕터:25장의 처리 완료했습니다.
# ge의 챕터:26장의 처리 완료했습니다.
# ge의 챕터:27장의 처리 완료했습니다.
# ge의 챕터:28장의 처리 완료했습니다.
# ge의 챕터:29장의 처리 완료했습니다.
# ge의 챕터:30장의 처리 완료했습니다.
# ge의 챕터:31장의 처리 완료했습니다.
# ge의 챕터:32장의 처리 완료했습니다.
# ge의 챕터:33장의 처리 완료했습니다.
# ge의 챕터:34장의 처리 완료했습니다.
# ge의 챕터:35장의 처리 완료했습니다.
# ge의 챕터:36장의 처리 완료했습니다.
# ge의 챕터:37장의 처리 완료했습니다.
# ge의 챕터:38장의 처리 완료했습니다.
# ge의 챕터:39장의 처리 완료했습니다.
# ge의 챕터:40장의 처리 완료했습니다.
# ...

# %%
# Out:
# '50'
