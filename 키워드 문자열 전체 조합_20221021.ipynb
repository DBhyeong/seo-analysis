# %%
from itertools import product
from itertools import permutations
from itertools import combinations


#비대면

kw_g_1 = ['비대면',
'온라인',
]

#용도1

kw_g_2 = ['코딩',
'토익',
'수학',
'대학',
'중학생',
'초등',
'중등',
'고등',
'무료',
'영어',
'논술',
'유아',
'유치원',
'아동',
'기업'    
    
]


#용도2

kw_g_3 = ['녹화',
'영상',
'줌',
'동영상',
'zoom',
'인터넷',
'학교',
'면접'

]

#용도3

kw_g_4 = ['강의',
'수업',
'회의',
'교육',
'현강',
'프로그램',
'화면',
'인강'

]

#장비

kw_g_5 = ['장비',
'촬영',
'컨텐츠',
'콘텐츠쉽게만들기',
'방법',
'제작',
'잘하는법',
'편집',
'컨텐츠만들기'

]

#키워드 조합 2개


# kw_g_1 비대면
# kw_g_2 용도1
# kw_g_3 용도2
# kw_g_4 용도3
# kw_g_5 장비


#kw_g_2

for kw_1 in kw_g_2 : 
    for kw_2 in kw_g_3:
        comb_1 = kw_1 + " " + kw_2
        print("용도1 + 용도2" + ',' + comb_1)


for kw_1 in kw_g_2 : 
    for kw_2 in kw_g_4:
        comb_1 = kw_1 + " " + kw_2
        print("용도1 + 용도3" + ',' + comb_1)

for kw_1 in kw_g_2 : 
    for kw_2 in kw_g_5:
        comb_1 = kw_1 + " " + kw_2
        print("용도1 + 장비" + ',' + comb_1)


        
#kw_g_3

for kw_1 in kw_g_3 : 
    for kw_2 in kw_g_4:
        comb_1 = kw_1 + " " + kw_2
        print("용도2 + 용도3" + ',' + comb_1)


for kw_1 in kw_g_2 : 
    for kw_2 in kw_g_5:
        comb_1 = kw_1 + " " + kw_2
        print("용도2 + 장비" + ',' + comb_1)


#kw_g_4

for kw_1 in kw_g_4 : 
    for kw_2 in kw_g_5:
        comb_1 = kw_1 + " " + kw_2
        print("용도3 + 장비" + ',' + comb_1)
# Out:
# 용도1 + 용도2,코딩 녹화
# 용도1 + 용도2,코딩 영상
# 용도1 + 용도2,코딩 줌
# 용도1 + 용도2,코딩 동영상
# 용도1 + 용도2,코딩 zoom
# 용도1 + 용도2,코딩 인터넷
# 용도1 + 용도2,코딩 학교
# 용도1 + 용도2,코딩 면접
# 용도1 + 용도2,토익 녹화
# 용도1 + 용도2,토익 영상
# 용도1 + 용도2,토익 줌
# 용도1 + 용도2,토익 동영상
# 용도1 + 용도2,토익 zoom
# 용도1 + 용도2,토익 인터넷
# 용도1 + 용도2,토익 학교
# 용도1 + 용도2,토익 면접
# 용도1 + 용도2,수학 녹화
# 용도1 + 용도2,수학 영상
# 용도1 + 용도2,수학 줌
# 용도1 + 용도2,수학 동영상
# 용도1 + 용도2,수학 zoom
# 용도1 + 용도2,수학 인터넷
# 용도1 + 용도2,수학 학교
# 용도1 + 용도2,수학 면접
# 용도1 + 용도2,대학 녹화
# 용도1 + 용도2,대학 영상
# 용도1 + 용도2,대학 줌
# 용도1 + 용도2,대학 동영상
# 용도1 + 용도2,대학 zoom
# 용도1 + 용도2,대학 인터넷
# 용도1 + 용도2,대학 학교
# 용도1 + 용도2,대학 면접
# 용도1 + 용도2,중학생 녹화
# 용도1 + 용도2,중학생 영상
# 용도1 + 용도2,중학생 줌
# 용도1 + 용도2,중학생 동영상
# 용도1 + 용도2,중학생 zoom
# 용도1 + 용도2,중학생 인터넷
# 용도1 + 용도2,중학생 학교
# 용도1 + 용도2,중학생 면접
# 용도1 + 용도2,초등 녹화
# 용도1 + 용도2,초등 영상
# 용도1 + 용도2,초등 줌
# 용도1 + 용도2,초등 동영상
# 용도1 + 용도2,초등 zoom
# 용도1 + 용도2,초등 인터넷
# 용도1 + 용도2,초등 학교
# 용도1 + 용도2,초등 면접
# 용도1 + 용도2,중등 녹화
# 용도1 + 용도2,중등 영상
# 용도1 + 용도2,중등 줌
# 용도1 + 용도2,중등 동영상
# 용도1 + 용도2,중등 zoom
# ...
