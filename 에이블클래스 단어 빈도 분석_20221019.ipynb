# %%
from konlpy.tag import Kkma, Okt, Komoran, Hannanum
from konlpy.utils import pprint
from collections import  Counter

f = open (r"C:\Users\user\Desktop\hanspell_1_txt.txt", 'r', encoding='utf-8')

text = f.read()

#Kkma 객체 생성
#okt = Kkma()
#noun = okt.nouns(text)

#count = Counter(noun)

#명사 빈도 카운트

#noun_list = count.most_common(20)
#for v in noun_list :
#    print("Kkma 기준 : "+ str(v))


#Okt 객체 생성
okt = Okt()
noun = okt.nouns(text)

count = Counter(noun)

#명사 빈도 카운트

noun_list = count.most_common(100)
for v in noun_list :
    print("Okt 기준 : " + str(v))

    
#Komoran 객체 생성
#okt = Komoran()
#noun = okt.nouns(text)

#count = Counter(noun)

#명사 빈도 카운트

#noun_list = count.most_common(10)
#for v in noun_list :
#    print("Komoran 기준: " + str(v))

    
#Hannanum 객체 생성
okt = Hannanum()
noun = okt.nouns(text)

count = Counter(noun)

#명사 빈도 카운트

noun_list = count.most_common(100)
for v in noun_list :
    print("Hannanum 기준: " + str(v))
# Out:
# Okt 기준 : ('빔', 4028)
# Okt 기준 : ('전자칠판', 4004)
# Okt 기준 : ('에듀', 2872)
# Okt 기준 : ('수업', 2612)
# Okt 기준 : ('학원', 2116)
# Okt 기준 : ('판서', 2024)
# Okt 기준 : ('선생님', 1705)
# Okt 기준 : ('수', 1689)
# Okt 기준 : ('프로젝터', 1579)
# Okt 기준 : ('칠판', 1519)
# Okt 기준 : ('뷰', 1476)
# Okt 기준 : ('설치', 1437)
# Okt 기준 : ('사용', 1254)
# Okt 기준 : ('교육', 1187)
# Okt 기준 : ('프로그램', 1100)
# Okt 기준 : ('스마트', 900)
# Okt 기준 : ('기능', 875)
# Okt 기준 : ('학교', 867)
# Okt 기준 : ('시연', 860)
# Okt 기준 : ('인치', 700)
# Okt 기준 : ('학생', 650)
# Okt 기준 : ('구매', 631)
# Okt 기준 : ('터치', 616)
# Okt 기준 : ('경우', 599)
# Okt 기준 : ('등', 597)
# Okt 기준 : ('환경', 587)
# Okt 기준 : ('위해', 569)
# Okt 기준 : ('전용', 560)
# Okt 기준 : ('활용', 533)
# Okt 기준 : ('제품', 505)
# Okt 기준 : ('상담', 474)
# Okt 기준 : ('교재', 440)
# Okt 기준 : ('화면', 434)
# Okt 기준 : ('시간', 420)
# Okt 기준 : ('형', 417)
# Okt 기준 : ('기존', 414)
# Okt 기준 : ('초점', 400)
# Okt 기준 : ('일반', 382)
# Okt 기준 : ('펜', 381)
# Okt 기준 : ('듀빔', 376)
# Okt 기준 : ('진행', 368)
# Okt 기준 : ('방식', 362)
# Okt 기준 : ('시', 358)
# Okt 기준 : ('전자', 358)
# Okt 기준 : ('위', 357)
# Okt 기준 : ('문제', 353)
# Okt 기준 : ('더', 348)
# Okt 기준 : ('단', 346)
# Okt 기준 : ('통해', 341)
# Okt 기준 : ('직접', 324)
# Okt 기준 : ('용', 322)
# Okt 기준 : ('강의실', 322)
# Okt 기준 : ('중', 307)
# Okt 기준 : ('목적', 298)
# Okt 기준 : ('선사', 292)
# Okt 기준 : ('센서', 290)
# Okt 기준 : ('제공', 289)
# Okt 기준 : ('분필', 279)
# Okt 기준 : ('공간', 275)
# Okt 기준 : ('녹화', 275)
# Okt 기준 : ('법랑', 275)
# Okt 기준 : ('등급', 274)
# Okt 기준 : ('발생', 274)
# Okt 기준 : ('바로', 273)
# Okt 기준 : ('전', 266)
# Okt 기준 : ('무료', 254)
# Okt 기준 : ('확인', 252)
# Okt 기준 : ('것', 252)
# Okt 기준 : ('모드', 250)
# Okt 기준 : ('화이트보드', 248)
# Okt 기준 : ('를', 248)
# Okt 기준 : ('선택', 247)
# Okt 기준 : ('때', 241)
# Okt 기준 : ('네이버', 240)
# Okt 기준 : ('추천', 234)
# Okt 기준 : ('집중', 230)
# Okt 기준 : ('수학', 230)
# Okt 기준 : ('디럭스', 228)
# Okt 기준 : ('교실', 225)
# Okt 기준 : ('제작', 220)
# Okt 기준 : ('영상', 218)
# Okt 기준 : ('가격', 215)
# Okt 기준 : ('확대', 214)
# Okt 기준 : ('판', 210)
# Okt 기준 : ('및', 209)
# Okt 기준 : ('신청', 207)
# Okt 기준 : ('실제', 204)
# Okt 기준 : ('전화', 204)
# Okt 기준 : ('요', 200)
# Okt 기준 : ('경쟁력', 200)
# Okt 기준 : ('곳', 197)
# Okt 기준 : ('영어', 195)
# Okt 기준 : ('문의', 192)
# Okt 기준 : ('교습', 191)
# Okt 기준 : ('체험', 190)
# Okt 기준 : ('땐', 188)
# Okt 기준 : ('아래', 186)
# Okt 기준 : ('해당', 184)
# Okt 기준 : ('추가', 183)
# Okt 기준 : ('화질', 183)
# Hannanum 기준: ('수업', 2280)
# Hannanum 기준: ('전자칠판', 2237)
# Hannanum 기준: ('수', 1808)
# Hannanum 기준: ('판', 1662)
# Hannanum 기준: ('학원', 1607)
# Hannanum 기준: ('칠판', 1477)
# Hannanum 기준: ('선생님', 1455)
# Hannanum 기준: ('뷰', 1412)
# Hannanum 기준: ('설치', 1358)
# Hannanum 기준: ('사용', 1189)
# Hannanum 기준: ('에듀빔전자칠판', 1162)
# Hannanum 기준: ('라클', 1118)
# Hannanum 기준: ('프로그램', 1087)
# Hannanum 기준: ('프로젝터', 982)
# Hannanum 기준: ('교육', 898)
# Hannanum 기준: ('시연', 851)
# Hannanum 기준: ('가능', 846)
# Hannanum 기준: ('기능', 728)
# Hannanum 기준: ('스마트', 694)
# Hannanum 기준: ('학교', 622)
# Hannanum 기준: ('경우', 596)
# Hannanum 기준: ('에듀빔', 587)
# Hannanum 기준: ('등', 586)
# Hannanum 기준: ('빔프로젝터', 584)
# Hannanum 기준: ('구매', 583)
# Hannanum 기준: ('학생들', 514)
