# %%
from konlpy.tag import Kkma, Okt, Komoran, Hannanum
from konlpy.utils import pprint
from collections import  Counter

f = open (r"C:\Users\user\Desktop\hanspell_positive_words.txt", 'r', encoding='utf-8')

text = f.read()

#Kkma 객체 생성
#okt = Kkma()
#noun = okt.nouns(text)

#count = Counter(noun)

#명사 빈도 카운트

#noun_list = count.most_common(20)
#for v in noun_list :
#    print("Kkma 기준 : "+ str(v))


#Okt 객체 생성
okt = Okt()
noun = okt.nouns(text)

count = Counter(noun)

#명사 빈도 카운트

noun_list = count.most_common(100)
for v in noun_list :
    v = list((v))  #튜플 리스트화
    if len(v[0]) > 1 :  #단어 1자리 수 제거
        print("Okt 기준 : " + str(v[0]) + ',' + str(v[1]))
    #if len(v.values) > 1 :
        #print("Okt 기준 : " + str(v))


#Komoran 객체 생성
#okt = Komoran()
#noun = okt.nouns(text)

#count = Counter(noun)

#명사 빈도 카운트

#noun_list = count.most_common(10)
#for v in noun_list :
#    print("Komoran 기준: " + str(v))

    
#Hannanum 객체 생성
okt = Hannanum()
noun = okt.nouns(text)

count = Counter(noun)

#명사 빈도 카운트

noun_list = count.most_common(100)
for v in noun_list :
    v = list((v))  #튜플 리스트화
    if len(v[0]) > 1 :  #단어 1자리 수 제거
        print("Hannanum 기준 : " + str(v[0]) + ',' + str(v[1]))
    #if len(v.values) > 1 :
        #print("Okt 기준 : " + str(v))
# Out:
# Okt 기준 : 수업,434
# Okt 기준 : 전자칠판,270
# Okt 기준 : 선생님,245
# Okt 기준 : 판서,204
# Okt 기준 : 에듀,174
# Okt 기준 : 칠판,151
# Okt 기준 : 설치,150
# Okt 기준 : 학생,140
# Okt 기준 : 사용,129
# Okt 기준 : 프로젝터,125
# Okt 기준 : 추천,118
# Okt 기준 : 환경,113
# Okt 기준 : 학원,100
# Okt 기준 : 활용,94
# Okt 기준 : 기능,90
# Okt 기준 : 터치,89
# Okt 기준 : 프로그램,89
# Okt 기준 : 교육,85
# Okt 기준 : 장점,78
# Okt 기준 : 스마트,68
# Okt 기준 : 교재,64
# Okt 기준 : 문제,60
# Okt 기준 : 화면,60
# Okt 기준 : 화질,51
# Okt 기준 : 해결,50
# Okt 기준 : 제품,48
# Okt 기준 : 공간,46
# Okt 기준 : 시연,45
# Okt 기준 : 확대,44
# Okt 기준 : 집중,43
# Okt 기준 : 진행,42
# Okt 기준 : 피로,40
# Okt 기준 : 기존,40
# Okt 기준 : 강의실,39
# Okt 기준 : 강의,39
# Okt 기준 : 덕분,39
# Okt 기준 : 제공,37
# Okt 기준 : 등급,37
# Okt 기준 : 방식,36
# Okt 기준 : 효율,35
# Okt 기준 : 학교,34
# Okt 기준 : 구매,32
# Okt 기준 : 방해,32
# Okt 기준 : 분필,31
# Okt 기준 : 전용,31
# Okt 기준 : 시간,31
# Okt 기준 : 전자,30
# Okt 기준 : 최적화,30
# Okt 기준 : 플래티넘,29
# Okt 기준 : 걱정,29
# Okt 기준 : 실제,28
# Okt 기준 : 그림자,28
# Okt 기준 : 경우,27
# Okt 기준 : 초점,26
# Okt 기준 : 크기,25
# Okt 기준 : 이용,25
# Okt 기준 : 스크린,25
# ...
