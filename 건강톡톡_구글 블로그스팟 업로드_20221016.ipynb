# %%
# 구글 블로거 API 인증 (2번 해야됨)

import sys
import os
import pickle
from oauth2client import client
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request

#hongdaearea.blogspot.com 

BLOG_ID = "7084355431426392649"   # hongdaearea.blogspot.com    잡부정보 
#SCOPES = ['https://www.googleapis.com/auth/blogger', 'https://www.googleapis.com/auth/drive.file']

SCOPES = ['https://www.googleapis.com/auth/blogger']

def get_blogger_service_obj():
    creds = None
    if os.path.exists('auto_token.pickle'):
        with open('auto_token.pickle', 'rb') as token:
            creds = pickle.load(token)
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'C:/Users/user/blogger/client_secret.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('auto_token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    blog_service = build('blogger', 'v3', credentials=creds)
    drive_service = build('drive', 'v3', credentials=creds)

    return drive_service,blog_service

drive_handler, blog_handler = get_blogger_service_obj()

# %%
import os
import time


#이미지
img_urls = [ 
'http://15.165.222.35/u40gwx.png',
'http://15.165.222.35/34ehbt.png',
'http://15.165.222.35/lyrhcv.png',
'http://15.165.222.35/4hp36l.png',
'http://15.165.222.35/fwfbef.jpg',
'http://15.165.222.35/lgldvq.png',
'http://15.165.222.35/w0rzw3.png',
'http://15.165.222.35/bxmo6y.jpg',
'http://15.165.222.35/emol1o.jpg',
'http://15.165.222.35/8kqa92.png',
'http://15.165.222.35/3vocz0.png',
'http://15.165.222.35/jz8g8i.png',
'http://15.165.222.35/ux5oq9.png',
'http://15.165.222.35/n48ymf.png',
'http://15.165.222.35/99fcmq.png',
'http://15.165.222.35/9i2o8c.png',
'http://15.165.222.35/utudzo.png',
'http://15.165.222.35/0af02t.png',
'http://15.165.222.35/cxs5pa.png',
'http://15.165.222.35/r7t3y5.png',
'http://15.165.222.35/972wbf.png',
'http://15.165.222.35/rsszsq.png',
'http://15.165.222.35/lywbtv.png',
'http://15.165.222.35/0ayt2w.png',
'http://15.165.222.35/wdbfg7.jpg',
'http://15.165.222.35/zlb8zi.png',
'http://15.165.222.35/3u1c0c.png',
'http://15.165.222.35/t4z7py.png',
'http://15.165.222.35/8xgcp9.png',
'http://15.165.222.35/7u03v9.png',
'http://15.165.222.35/iahp5x.png',
'http://15.165.222.35/6p8chm.png',
'http://15.165.222.35/kc4rta.png',
'http://15.165.222.35/1csn2g.png',
'http://15.165.222.35/jrih44.png',
'http://15.165.222.35/pkeo74.png',
'http://15.165.222.35/xo86zo.png',
'http://15.165.222.35/9trkaf.png',
'http://15.165.222.35/pg6r7w.png',
'http://15.165.222.35/6x99am.png',
'http://15.165.222.35/lyy6xz.png',
'http://15.165.222.35/ezv10e.png',
'http://15.165.222.35/v1wwer.png',
'http://15.165.222.35/b2mc7n.png',
'http://15.165.222.35/5odkfb.png',
'http://15.165.222.35/2eymtt.png',
'http://15.165.222.35/u359f4.png',
'http://15.165.222.35/tg4x18.png',
'http://15.165.222.35/un2nkq.png',
'http://15.165.222.35/6wue06.png',
'http://15.165.222.35/3gnr8y.png',
'http://15.165.222.35/u40gwx.png',
'http://15.165.222.35/0zj5s6.png',
'http://15.165.222.35/34ehbt.png',
'http://15.165.222.35/lyrhcv.png',
'http://15.165.222.35/4hp36l.png',
'http://15.165.222.35/lgldvq.png',
'http://15.165.222.35/w0rzw3.png',
'http://15.165.222.35/u3620l.png',
'http://15.165.222.35/zt3n36.png',
'http://15.165.222.35/5e3ip7.png',
'C:/Users/user/raw/down/health/1893/1893.txt',
'C:/Users/user/raw/down/health/1894/1894.txt',
'C:/Users/user/raw/down/health/1896/1896.txt',
'C:/Users/user/raw/down/health/1897/1897.txt',
'C:/Users/user/raw/down/health/1899/1899.txt',
'C:/Users/user/raw/down/health/1900/1900.txt',
'C:/Users/user/raw/down/health/1902/1902.txt',
'C:/Users/user/raw/down/health/1903/1903.txt',
'C:/Users/user/raw/down/health/1905/1905.txt',
'C:/Users/user/raw/down/health/1906/1906.txt',
'C:/Users/user/raw/down/health/1908/1908.txt',
'C:/Users/user/raw/down/health/1909/1909.txt',
'C:/Users/user/raw/down/health/1911/1911.txt',
'C:/Users/user/raw/down/health/1912/1912.txt',
'C:/Users/user/raw/down/health/1914/1914.txt',
'C:/Users/user/raw/down/health/1915/1915.txt',
'C:/Users/user/raw/down/health/1917/1917.txt',
'C:/Users/user/raw/down/health/1918/1918.txt',
'C:/Users/user/raw/down/health/1920/1920.txt',
'C:/Users/user/raw/down/health/1921/1921.txt',
'C:/Users/user/raw/down/health/1923/1923.txt',
'C:/Users/user/raw/down/health/1924/1924.txt',
'C:/Users/user/raw/down/health/1925/1925.txt',
'C:/Users/user/raw/down/health/1926/1926.txt',
'C:/Users/user/raw/down/health/1927/1927.txt',
'C:/Users/user/raw/down/health/1928/1928.txt',
'C:/Users/user/raw/down/health/1929/1929.txt',
'C:/Users/user/raw/down/health/1930/1930.txt',
'C:/Users/user/raw/down/health/1931/1931.txt',
'C:/Users/user/raw/down/health/1932/1932.txt',
'C:/Users/user/raw/down/health/1933/1933.txt',
'C:/Users/user/raw/down/health/1934/1934.txt',
'C:/Users/user/raw/down/health/1935/1935.txt',
'C:/Users/user/raw/down/health/1936/1936.txt',
'C:/Users/user/raw/down/health/1937/1937.txt'
]

#n = 0


for img_url,txt_file in zip(img_urls, txt_files) :
    #path = 'C:/Users/user/raw/down/health/'+str(i)+'/'
    #file_list = os.listdir(path)
    #file_list_png = [file for file in file_list if file.endswith(".txt")]
    
    file_list_png = [txt_file] #리스트화
    
    for blog_content in file_list_png :
        #txt_file_directory = str(path) + str(blog_content)
        txt_file_directory = str(blog_content)
        
        f = open(txt_file_directory, 'r', encoding='utf-8')  #메모장 파일열기
        content_list = f.readlines() #본문  
        blogger_title = content_list[0]
        blogger_title_2 = blogger_title.replace("\ufeff", "")
        content_list_2 = []
        for i in content_list : 
            i = i.replace("\ufeff", "")
            i_text = '<p>' + str(i) + '</p>'  #html 넣자
            content_list_2.append(i_text)


        #이미지 삽입란
        
        #img_url = img_url[n] 
        
        img_url = '"' + str(img_url) + '"'

        content_list_3 = """
        <div style="text-align: left;">
         <div class="separator" style="clear: both; text-align: center;">
          <p style="text-align: left;">
          </p>
         </div>
        </div>
        <div style="text-align: left;">
         <div class="separator" style="clear: both; text-align: center;">
          <a href="""+str(img_url)+""" imageanchor="1" style="margin-left: 1em; margin-right: 1em;">
           <img border="0" data-original-height="640" data-original-width="720" height="284" src="""+str(img_url)+""" width="320"/>
          </a>
         </div>
         <br/>
         <pre style="background-color: white; border-radius: 0px; border: 0px; box-sizing: border-box; font-family: D2Coding; font-size: 12px; line-height: inherit; margin-bottom: 0px; margin-top: 0px; overflow-wrap: break-word; overflow: auto; padding: 1px 0px; vertical-align: baseline; white-space: pre-wrap; word-break: break-all;"><br/></pre>
        </div>

        """

        #제목 

        content_list_3 += """
        </h1>
        <h1 style="text-align: left;">
         <b>
          """+blogger_title_2+"""
         </b>
        </h1>

        """


        #본문

        content_list_3 += str(content_list_2)
        content_list_3 = content_list_3.replace("[", "")
        content_list_3 = content_list_3.replace("\'", "")
        content_list_3 = content_list_3.replace("\\n", "")
        content_list_3 = content_list_3.replace(">,", ">")
        content_list_3 = content_list_3.replace("\\u200b", "")
        content_list_3 = content_list_3.replace('\'', '')
        content_list_3 = content_list_3.replace(']', '')

        #print(content_list_3)    

        keyword = str(blogger_title)

        data = {
        'title': blogger_title_2[:50], #제목
        'content': content_list_3, #본문
        'labels' : keyword[:50], #해시태그
        'blog': {
            'id': BLOG_ID, # The identifier of the Blog that contains this Post.
          },}
        posts = blog_handler.posts()
        res = posts.insert(blogId=BLOG_ID, body=data, isDraft=False, fetchImages=True).execute() 
        #res

        f.close() #파일닫기
        print(str(blogger_title_2)+ "의 포스팅 완료")
    time.sleep(30) #30초
    #n+=10
# Out:
# 균형 잡힌 식사를 하고 잠을 충분히 자고, 운동을 하는 등의 생활습관은 건강을 유지하기 위해 좋은 것들이다. 미국 보스턴 대학교 메디컬센터 마이클 홀릭 박사는 "하지만 이런 건강 습관을 가져도 조금만 소홀히 하면 고혈압과 당뇨병 위험을 2.5배나 높이는 요소가 한 가지 있다"고 말한다.
# 의 포스팅 완료
# 건강에 여러모로 좋은 채소들 중에서도 최고의 채소에는 어떤 것이 있을까. '치트시트닷컴'이 미국 농무부의 데이터를 토대로 칼로리와 비타민, 루테인, 칼륨, 섬유질 함량 등을 고려해 채소의 순위 정했다.
# 의 포스팅 완료
# 남성보다 여성에게 건강상 혜택이 큰 음식이 있다. 임신, 폐경 등으로 인한 신체 변화와 건강상 이슈 차이 때문이다.
# 의 포스팅 완료
# 비만 전문가들은 "과체중이나 비만인 사람을 많이 대하지만 먹는 걸 그렇게 좋아하지 않는 경우도 많다"고 말한다. 사실 에너지의 균형이 이뤄지지 않고 섭취하는 칼로리와 배출하는 칼로리에 차이가 생기는 것이 비만의 이유인 것은 분명하다.
# 의 포스팅 완료
# ♡덕을 쌓아가는 인생 지침서ㅡ
# 의 포스팅 완료
# 코골이와 수면 무호흡증은 가족을 포함해 대인 관계에 영향을 미친다.
# 의 포스팅 완료
# 관절염에 대해 잘못 알려진 사실 4가지
# 의 포스팅 완료
# □■긍정적인 자극을 주는 명언□■
# 의 포스팅 완료
# □■이런 사람은 걱정하지 않습니다□■
# 의 포스팅 완료
# 약 안 먹고 자연스럽게 혈당 낮추는 방법 3가지
# 의 포스팅 완료
# 감기에 잘 걸리지 않는 사람이 있는가 하면 겨우내 기침을 하고 콜록대는 사람이 있다. 양자 간에는 몇 가지 중요한 습관상의 차이가 있다.
# 의 포스팅 완료
# 식중독이란 병원균을 비롯해 미생물 독소, 화학 물질 및 기타 독성 물질에 오염된 음식을 먹은 뒤 발생하는 질병을 말한다.
# 의 포스팅 완료
# 보리 음료라는 말을 들으면 먼저 맥주를 떠올릴 수 있다. 하지만 보리 음료가 맥주와 가장 다른 점은 발효 과정을 거치지 않는다는 것이다.
# ...

# %%
# Out:
# '\ufeff균형 잡힌 식사를 하고 잠을 충분히 자고, 운동을 하는 등의 생활습관은 건강을 유지하기 '

# %%
img_urls = ['http://15.165.222.35/nmtzyd.jpg' 
]


txt_files = ['C:/Users/user/raw/down/health/17/17.txt'

]
#n = 0


for img_url,txt_file in zip(img_urls, txt_files) :
    file_list_png = [txt_file]
    print(file_list_png)
# Out:
# ['C:/Users/user/raw/down/health/17/17.txt']

# %%
#https://photos.google.com/lr/photo/AI9aVGFuvUt3Dfrg6dq5koIYbWWAjhNxl_ARTMOJxZ2hTTaeOStTK9_R6CvAa0rZPyrEk3bodgG2-0_muVKfKGoPyTg0mDT7JA

for blog_content in file_list_png :
    txt_file_directory = str(path) + str(blog_content)
    f = open(txt_file_directory, 'r', encoding='utf-8')  #메모장 파일열기
    content_list = f.readlines() #본문  
    blogger_title = content_list[0]
    blogger_title_2 = blogger_title.replace("\ufeff", "")
    content_list_2 = []
    for i in content_list : 
        i = i.replace("\ufeff", "")
        i_text = '<p>' + str(i) + '</p>'  #html 넣자
        content_list_2.append(i_text)
    
    
    #이미지 삽입란
    
    img_url = 'http://healtalk.net/api/appimage/47.jpeg'
    img_url = '"' + str(img_url) + '"'
    
    content_list_3 = """
    <div style="text-align: left;">
     <div class="separator" style="clear: both; text-align: center;">
      <p style="text-align: left;">
      </p>
     </div>
    </div>
    <div style="text-align: left;">
     <div class="separator" style="clear: both; text-align: center;">
      <a href="""+str(img_url)+""" imageanchor="1" style="margin-left: 1em; margin-right: 1em;">
       <img border="0" data-original-height="640" data-original-width="720" height="284" src="""+str(img_url)+""" width="320"/>
      </a>
     </div>
     <br/>
     <pre style="background-color: white; border-radius: 0px; border: 0px; box-sizing: border-box; font-family: D2Coding; font-size: 12px; line-height: inherit; margin-bottom: 0px; margin-top: 0px; overflow-wrap: break-word; overflow: auto; padding: 1px 0px; vertical-align: baseline; white-space: pre-wrap; word-break: break-all;"><br/></pre>
    </div>

    """
    
    #제목 
    
    content_list_3 += """
    </h1>
    <h1 style="text-align: left;">
     <b>
      """+blogger_title_2+"""
     </b>
    </h1>

    """

    
    #본문
    
    content_list_3 += str(content_list_2)
    content_list_3 = content_list_3.replace("[", "")
    content_list_3 = content_list_3.replace("\'", "")
    content_list_3 = content_list_3.replace("\\n", "")
    content_list_3 = content_list_3.replace(">,", ">")
    content_list_3 = content_list_3.replace("\\u200b", "")
    content_list_3 = content_list_3.replace('\'', '')
    content_list_3 = content_list_3.replace(']', '')
    
    print(content_list_3)
# Out:
#     <div style="text-align: left;">
#      <div class="separator" style="clear: both; text-align: center;">
#       <p style="text-align: left;">
#       </p>
#      </div>
#     </div>
#     <div style="text-align: left;">
#      <div class="separator" style="clear: both; text-align: center;">
#       <a href="https://doc-0o-6c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/o20uti8rdt0tijt63k1ef571r21f2vbt/1665892650000/06556411834618159015/*/1K4jBrosbweN5At7rcG0DB2yq1XWFTpkt?uuid=5c9ac8e0-3e8e-4547-aa0b-e651865e3e83" imageanchor="1" style="margin-left: 1em; margin-right: 1em;">
#        <img border="0" data-original-height="640" data-original-width="720" height="284" src="https://doc-0o-6c-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/o20uti8rdt0tijt63k1ef571r21f2vbt/1665892650000/06556411834618159015/*/1K4jBrosbweN5At7rcG0DB2yq1XWFTpkt?uuid=5c9ac8e0-3e8e-4547-aa0b-e651865e3e83" width="320"/>
#       </a>
#      </div>
# ...

# %%
# Out:
# '"'
