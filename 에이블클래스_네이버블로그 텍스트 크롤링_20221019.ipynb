    raw = requests.get("https://blog.naver.com/PostView.naver?blogId={}&logNo={}".format(blogId, postId))  #협찬
    html = BeautifulSoup(raw.text, 'html.parser') #긁기

    title = html.find("meta", property= "og:title") #제목
    desc = html.find("meta", property= "og:description") #스니펫

    content_txt = []
    content_txt_2 = []
    
    title_2 = title['content'] #제목
    content = html.find("div", {"class" : "se-main-container"}).text #본문
    
    content = content.replace('\n', '') #필터링
    
    #content_txt.append(content)
    
    
    f.write(str(content) + '\n\n')
    
    #desc_2 = desc['content']
    #desc_2 = desc_2.replace("...", "")
    #print(desc_2) 

    #content_2 = content.readlines()


    #for i in content_txt :
        #nline = i.replace("\n", "")
        #nline = nline.replace("\u200b", "")
        #nline = nline.replace('↓', "") 
        #f.write(str(nline) +'\n')
    #print(content_txt_2) #확인

    #print(content_txt_2)

    #for j in content_txt_2 :
    #    f.write(j + '\n')

    print(str(title_2) +" 의 페이지 크롤링 완료")
    #content_text = str(content_txt_2)  #최종본문
    
    time.sleep(1) #1초

print("최종완료")
f.close()
    #print("제목: " + str(title_2))  #제목확인
    #print("-------------------------------------------본문----------------------------------------------")
    #print(content_text) #최종본문확인
# Out:
# 전자칠판 기능 궁금하다면? 이 글 하나로 끝! 종결! 의 페이지 크롤링 완료
# 일반 빔프로젝터 사용하다 교육용 전자칠판으로 교체한 이유 의 페이지 크롤링 완료
# 학교 학원 선생님들이 추천하는 데에는 이유가 다~ 있습니다. 의 페이지 크롤링 완료
# 디지털보드 강의실에 설치했더니 수업이 2배 빨라집니다 의 페이지 크롤링 완료
# 초중고 학교 학원이라면 스마트칠판 무조건 설치해야 합니다 의 페이지 크롤링 완료
# 디지털 전자칠판으로 편하게 수업하는 방법 의 페이지 크롤링 완료
# 스마트전자칠판 구매해야 하는 1가지 이유 의 페이지 크롤링 완료
# 2022 에듀테크코리아페어 전자칠판의 모든 것 의 페이지 크롤링 완료
# 가격과 품질 모두 잡은 갓성비전자칠판 구매 방법 의 페이지 크롤링 완료
# 학교 전자칠판 빔프로젝터 스크린과 함께 사용하는 방법 의 페이지 크롤링 완료
# 인터넷전자칠판 활용하는 꿀팁 3가지 대방출 의 페이지 크롤링 완료
# 영어를 가르치신다면 전자칠판 무조건 설치해야 하는 이유 의 페이지 크롤링 완료
# 전자칠판 터치펜 말고도 분필 보드마카 전부 사용 가능 의 페이지 크롤링 완료
# 학교 학원 교실 전자칠판 구매 전 궁금증 질문 Q&A 총정리 의 페이지 크롤링 완료
# 신규 학원일수록 디지털칠판을 구매해야 하는 이유 의 페이지 크롤링 완료
# 학원 수업에 최적화된 전자칠판 이렇게 사용하세요 의 페이지 크롤링 완료
# 판서 스트레스는 날리고 학생들 집중력 2배 향상시키는 팁 의 페이지 크롤링 완료
# 학원 소방법 체크하고 인테리어에 맞는 전자칠판 설치하세요 의 페이지 크롤링 완료
# 회사에도 전자칠판 한 대만 있으면 회의나 교육에 안성맞춤 의 페이지 크롤링 완료
# 빔프로젝터 전자칠판으로 바꾸고 수업이 2배 편리해진 이유 의 페이지 크롤링 완료
# 학교 학원 중고등학교 2학기 내신 준비 '이것'으로 종결 의 페이지 크롤링 완료
# 학원전자칠판 구매하기 전에 알아야 하는 3가지 의 페이지 크롤링 완료
# ...
