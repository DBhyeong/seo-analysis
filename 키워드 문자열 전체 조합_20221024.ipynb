# %%
from itertools import product
from itertools import permutations
from itertools import combinations


#학원

kw_g_1 = [ '서울',
'경기도',
'부산',
'경남',
'인천',
'경북',
'대구',
'충남',
'전남',
'전북',
'충북',
'강원도',
'대전',
'광주',
'울산',
'세종',
'수원',
'고양',
'용인',
'성남',
'화성',
'부천',
'남양',
'안산',
'평택',
'안양',
'시흥',
'파주',
'김포',
'의정',
'하남',
'광명',
'군포',
'양주',
'오산',
'이천',
'구리',
'안성',
'의왕',
'포천',
'양평',
'여주',
'동두',
'과천',
'가평',
'연천',
'원주',
'춘천',
'강릉',
'청주',
'천안',
'아산',
'충주',
'서산',
'당진',
'제천',
'논산',
'공주',
'전주',
'순천',
'익산',
'여우',
'군산',
'목포',
'광양',
'나주',
'정읍',
'창원',
'김해',
'포항',
'구미',
'양산',
'진주',
'경산',
'경주',
'거제',
'안동',
'김천',
'통영',
'칠곡',
'강남',
'청담',
'목동',
'대치동',
'분당',
'수성구',
'영통',
'동탄'
]

#지역

kw_g_2 = [ '재수학원',
'반수학원',
'공무원학원',
'9급공무원학원',
'경찰학원',
'소방학원',
'소방공무원학원',
'경찰공무원학원',
'군무원학원',
'7급공무원학원'
    
]


for kw_1 in kw_g_1 : 
    for kw_2 in kw_g_2 :
        comb_1 = kw_1 + " " + kw_2
        print("지역 + 학원" + ',' + comb_1)
# Out:
# 지역 + 학원,서울 재수학원
# 지역 + 학원,서울 반수학원
# 지역 + 학원,서울 공무원학원
# 지역 + 학원,서울 9급공무원학원
# 지역 + 학원,서울 경찰학원
# 지역 + 학원,서울 소방학원
# 지역 + 학원,서울 소방공무원학원
# 지역 + 학원,서울 경찰공무원학원
# 지역 + 학원,서울 군무원학원
# 지역 + 학원,서울 7급공무원학원
# 지역 + 학원,경기도 재수학원
# 지역 + 학원,경기도 반수학원
# 지역 + 학원,경기도 공무원학원
# 지역 + 학원,경기도 9급공무원학원
# 지역 + 학원,경기도 경찰학원
# 지역 + 학원,경기도 소방학원
# 지역 + 학원,경기도 소방공무원학원
# 지역 + 학원,경기도 경찰공무원학원
# 지역 + 학원,경기도 군무원학원
# 지역 + 학원,경기도 7급공무원학원
# 지역 + 학원,부산 재수학원
# 지역 + 학원,부산 반수학원
# 지역 + 학원,부산 공무원학원
# 지역 + 학원,부산 9급공무원학원
# 지역 + 학원,부산 경찰학원
# 지역 + 학원,부산 소방학원
# 지역 + 학원,부산 소방공무원학원
# 지역 + 학원,부산 경찰공무원학원
# 지역 + 학원,부산 군무원학원
# 지역 + 학원,부산 7급공무원학원
# 지역 + 학원,경남 재수학원
# 지역 + 학원,경남 반수학원
# 지역 + 학원,경남 공무원학원
# 지역 + 학원,경남 9급공무원학원
# 지역 + 학원,경남 경찰학원
# 지역 + 학원,경남 소방학원
# 지역 + 학원,경남 소방공무원학원
# 지역 + 학원,경남 경찰공무원학원
# 지역 + 학원,경남 군무원학원
# 지역 + 학원,경남 7급공무원학원
# 지역 + 학원,인천 재수학원
# 지역 + 학원,인천 반수학원
# 지역 + 학원,인천 공무원학원
# 지역 + 학원,인천 9급공무원학원
# 지역 + 학원,인천 경찰학원
# 지역 + 학원,인천 소방학원
# 지역 + 학원,인천 소방공무원학원
# 지역 + 학원,인천 경찰공무원학원
# 지역 + 학원,인천 군무원학원
# 지역 + 학원,인천 7급공무원학원
# 지역 + 학원,경북 재수학원
# ...
