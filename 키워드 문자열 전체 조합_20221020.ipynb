# %%
from itertools import product
from itertools import permutations
from itertools import combinations


#비대면

kw_g_1 = ['비대면',
'온라인',
]

#용도1

kw_g_2 = ['코딩',
'토익',
'수학',
'대학',
'중학생',
'초등',
'중등',
'고등',
'무료',
'영어',
'논술',
'유아',
'유치원',
'아동',
'기업'    
    
]


#용도2

kw_g_3 = ['녹화',
'영상',
'줌',
'동영상',
'zoom',
'인터넷',
'학교',
'면접'

]

#용도3

kw_g_4 = ['강의',
'수업',
'회의',
'교육',
'현강',
'프로그램',
'화면',
'인강'

]

#장비

kw_g_5 = ['장비',
'촬영',
'컨텐츠',
'콘텐츠쉽게만들기',
'방법',
'제작',
'잘하는법',
'편집',
'컨텐츠만들기'

]

#키워드 조합 2개


"""
for kw_1 in kw_g_1 :
    for kw_2 in kw_g_2 :
        comb_1 = kw_1 + " " + kw_2
        print("비대면 + 용도1" + ',' + comb_1)

for kw_1 in kw_g_1 :
    for kw_2 in kw_g_3 :
        comb_1 = kw_1 + " " + kw_2
        print("비대면 + 용도2" + ',' + comb_1)

        
for kw_1 in kw_g_1 :
    for kw_2 in kw_g_4 :
        comb_1 = kw_1 + " " + kw_2
        print("비대면 + 용도3" + ',' + comb_1)

        
for kw_1 in kw_g_1 :
    for kw_2 in kw_g_5 :
        comb_1 = kw_1 + " " + kw_2
        print("비대면 + 장비" + ',' + comb_1)

"""
#키워드 조합 (3개)
     
""" 
#비대면 + 용도1 + 용도2
for kw_1 in kw_g_1 :
    for kw_2 in kw_g_2 :
        comb_1 = kw_1 + " " + kw_2
        for kw_3 in kw_g_3 :
            comb_2 = kw_1 + " " + kw_2 + " " + kw_3
            print("비대면 + 용도1 + 용도2," + comb_2 )

#비대면 + 용도1 + 용도3   
for kw_1 in kw_g_1 :  
    for kw_2 in kw_g_2 :
        comb_1 = kw_1 + " " + kw_2
        for kw_3 in kw_g_4 :
            comb_2 = kw_1 + " " + kw_2 + " " + kw_3
            print("비대면 + 용도1 + 용도3," + comb_2 )

#비대면 + 용도1 + 장비
for kw_1 in kw_g_1 :  
    for kw_2 in kw_g_2 :
        comb_1 = kw_1 + " " + kw_2
        for kw_3 in kw_g_5 :
            comb_2 = kw_1 + " " + kw_2 + " " + kw_3
            print("비대면 + 용도1 + 장비," + comb_2 )


#비대면 + 용도2 + 용도3
for kw_1 in kw_g_1 :  
    for kw_2 in kw_g_3 :
        comb_1 = kw_1 + " " + kw_2
        for kw_3 in kw_g_4 :
            comb_2 = kw_1 + " " + kw_2 + " " + kw_3
            print("비대면 + 용도2 + 용도3," + comb_2 )


#비대면 + 용도2 + 장비
            
for kw_1 in kw_g_1 :  
    for kw_2 in kw_g_3 :
        comb_1 = kw_1 + " " + kw_2
        for kw_3 in kw_g_5 :
            comb_2 = kw_1 + " " + kw_2 + " " + kw_3
            print("비대면 + 용도2 + 장비," + comb_2 )
           

#비대면 + 용도3 + 장비 
            
for kw_1 in kw_g_1 :  
    for kw_2 in kw_g_4 :
        comb_1 = kw_1 + " " + kw_2
        for kw_3 in kw_g_5 :
            comb_2 = kw_1 + " " + kw_2 + " " + kw_3
            print("비대면 + 용도3 + 장비," + comb_2 )


"""


#키워드 조합 4개
                
#비대면 + 용도1 + 용도2 + 용도3

"""
for kw_1 in kw_g_1 : 
    for kw_2 in kw_g_2 :
        for kw_3 in kw_g_3 :
            for kw_4 in kw_g_4 :
                comb_1 = kw_1 + ' '+ kw_2 + ' ' + kw_3 + ' ' + kw_4
                print("비대면 + 용도1 + 용도2 + 용도3," + comb_1)



#비대면 + 용도1 + 용도2 + 장비


for kw_1 in kw_g_1 : 
    for kw_2 in kw_g_2 :
        for kw_3 in kw_g_3 :
            for kw_4 in kw_g_5 :
                comb_1 = kw_1 + ' '+ kw_2 + ' ' + kw_3 + ' ' + kw_4
                print("비대면 + 용도1 + 용도2 + 장비," + comb_1)

"""               
#키워드 조합 (5개)

for kw_1 in kw_g_1 : 
    for kw_2 in kw_g_2 :
        for kw_3 in kw_g_3 :
            for kw_4 in kw_g_4 :
                for kw_5 in kw_g_5 :
                    comb_1 = kw_1 + ' '+ kw_2 + ' ' + kw_3 + ' ' + kw_4 + ' ' + kw_5
                    print("비대면 + 용도1 + 용도2 + 용도3+장비," + comb_1)
# Out:
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 강의 장비
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 강의 촬영
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 강의 컨텐츠
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 강의 콘텐츠쉽게만들기
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 강의 방법
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 강의 제작
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 강의 잘하는법
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 강의 편집
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 강의 컨텐츠만들기
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 수업 장비
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 수업 촬영
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 수업 컨텐츠
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 수업 콘텐츠쉽게만들기
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 수업 방법
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 수업 제작
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 수업 잘하는법
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 수업 편집
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 수업 컨텐츠만들기
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 회의 장비
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 회의 촬영
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 회의 컨텐츠
# 비대면 + 용도1 + 용도2 + 용도3+장비,비대면 코딩 녹화 회의 콘텐츠쉽게만들기
# ...
